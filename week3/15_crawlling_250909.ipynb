# %% [markdown]
# ### 웹 크롤링
# - 라이브러리
#     - requests
#         - 웹 서버에 요청을 보내고 응답을 받는 기능
#         - 응답 데이터는 문자나 바이트형으로 들어온다.
#     - bs4
#         - BeautifulSoup Class 사용
#         - html로 이루어진 문자 데이터를 parsing 작업을 통해서 데이터의 타입을 변경하여 데이터를 쉽게 추출하기 위한 기능
#         - html은 TAG(element)를 기준으로 하여 데이터 접근
#         - 웹의 기본 구조를 파악하고 사용하면 조금 더 쉽게 접근 가능
#     - selenium
#         - 웹 어플리케이션을 테스트하기 위한 라이브러리
#         - 웹 브라우저를 python code를 이용하여 제어
#             - 함수를 이용해서 특정 버튼을 클릭
#             - 특정 위치에 데이터를 대입
#         - 구글 크롬의 버전이 구버전인 경우에는 별도의 소프트웨어 설치가 필요

# %%
# 라이브러리 로드
import requests

# %%
# requests 안에 get() 함수를 이용하여 openapi에 요청을 보냈을 때는 
# data가 json, xml 형태로 들어온다.
# 그러면 naver에 요청을 보내면 어떤 데이터가 들어올까?

res = requests.get("http://www.naver.com")

# %%
res
# Out:
# <Response [200]>

# %%
# res에서 byte 형식으로 데이터를 받을 때는 content
# 문자열로 데이터를 확인할 때는 text
html_text = res.text

# %%
html_text
# Out:
# '   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="google-site-verification" content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_250828.css"> <link rel="canonical" href="https://www.naver.com/"> <link rel="alternate" media="only screen and (max-width: 767px)" href="https://m.naver.com/"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>\nwindow["EAGER-DATA"] = window["EAGER-DATA"] || {};\nwindow["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED","title":"바오캐럿 퍼플 개시했어요","url":"https://cafe.naver.com/smartbargain/1823660","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fcafeptthumb-phinf.pstatic.net%2FMjAyNTA5MDdfMjQg%2FMDAxNzU3MjQxMjY4NTE1.1MEfieRaeibRCI-YaZHaRaRkXDbGLC_tfP3x_FmD2cQg.4wTPegRNoMBQNoSBHrUlP_JQOUbwCZK-5UovP7SSOJsg.JPEG%2Foutput%EF%BC%BF3588364138.jpg%7C1458x1702%22&type=ff364_236&service=navermain"},"source":{"url":"https://cafe.naver.com/smartbargain","name":"스마트바겐 -  No.1 해외직구 & 국내 쇼핑 핫딜 총집합","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fcafeptthumb-phinf.pstatic.net%2FMjAyMTA3MjVfMTY5%2FMDAxNjI3MjIzMDUwMzAw.cgEpZs1C7uf5RKRDvaRByZNu_Ckm2LfF6JEdgE2t0x8g.ZGTCSceDAbZT16hFkBqCGdHD84SwH5wVCMLXU0iZOc8g.JPEG%2F%25EC%258A%25A4%25EB%25A7%2588%25ED%258A%25B8%25EB%25B0%2594%25EA%25B2%2590%25EB%25A1%259C%25EA%25B3%25A0-%25EB%25B8%2594%25EB%25A3%25A8.jpg%3Ftype%3Df40_40_mask%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6cce"},{"@type":"MATERIAL-PC-FEED","title":"턱 부각 고민 끝 #톤트#헤어컨설팅#모카무스","url":"https://tv.naver.com/h/83645624","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Ftvcast.phinf%2F20250905_40%2FaFQOk_1757082753096lCzxx_JPEG%2F30FE182C-24F3-48CC-9253-D947E5A7B9F9.jpg%22&type=ff364_236&service=navermain"},"source":{"url" ...

# %%
# html_text에서 네이버 글자를 찾아본다.
html_text.find('네이버')
# Out:
# 378

# %%
html_text[378:410]
# Out:
# '네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요'

# %%
# html 문서가 문자열로 이루어져있을때는 데이터를 추출하기가 어렵다.
# 별도의 라이브러리 설치
# !pip install bs4

# %%
# 라이브러리 로드
from bs4 import BeautifulSoup as bs

# %%
# BeautifulSoup Class 생성 = 클래스 안에 class를 대입한다.
# class 안의 데이터를 이용하여 추가적인 작업
# 해당 class를 생성할 때 생성자 함수 2개의 인자 필요
# 첫번째 인자: 문자열로 이루어진 html
# 두번째 인자: 첫번째 인자에 따라 변경 (html문서를 변환: html.parser)

soup = bs(html_text, 'html.parser')

# %%
soup
# Out:
#  <!DOCTYPE html>
#  <html class="fzoom" lang="ko"> <head> <meta charset="utf-8"/> <meta content="origin" name="Referrer"/> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <title>NAVER</title> <meta content="NAVER" name="apple-mobile-web-app-title"> <meta content="index,nofollow" name="robots"> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"> <meta content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g" name="google-site-verification"> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/> <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed"> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_250828.css" rel="stylesheet"/> <link href="https://www.naver.com/" rel="canonical"/> <link href="https://m.naver.com/" media="only screen and (max-width: 767px)" rel="alternate"/> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js"></script> <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED","title":"바오캐럿 퍼플 개시했어요","url":"https://cafe.naver.com/smartbargain/1823660","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fcafeptthumb-phinf.pstatic.net%2FMjAyNTA5MDdfMjQg%2FMDAxNzU3MjQxMjY4NTE1.1MEfieRaeibRCI-YaZHaRaRkXDbGLC_tfP3x_FmD2cQg.4wTPegRNoMBQNoSBHrUlP_JQOUbwCZK-5UovP7SSOJsg.JPEG%2Foutput%EF%BC%BF3588364138.jpg%7C1458x1702%22&type=ff364_236&service=navermain"},"source":{"url":"https://cafe.naver.com/smartbargain","name":"스마트바겐 -  No.1 해외직구 & 국내 쇼핑 핫딜 총집합","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fcafeptthumb-phinf.pstatic.net%2FMjAyMTA3MjVfMTY5%2FMDAxNjI3MjIzMDUwMzAw.cgEpZs1C7uf5RKRDvaRByZNu_Ckm2LfF6JEdgE2t0x8g.ZGTCSceDAbZT16hFkBqCGdHD84SwH5wVCMLXU0iZOc8g.JPEG%2F%25EC%258A%25A4%25EB%25A7%2588%25ED%258A%25B8%25EB%25B0%2594%25EA%25B2%2590%25EB%25A1%259C%25EA%25B3%25A0-%25EB%25B8%2594%25EB%25A3%25A8.jpg%3Ftype%3Df40_40_mask%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6cce"},{"@type":"MATERIAL-PC-FEED","title":"턱 부각 고민 끝 #톤트#헤어컨설팅#모카무스","url":"https://tv.naver.com/h/83645624","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Ftvcast.phinf%2F20250905_40%2FaFQOk_1757082753096lCzxx_JPEG%2F30FE182C-24F3-48CC-9253-D947E5A7B9F9.jpg%22&type=ff364_236&service=navermain"},"source":{"url":"https://tv.naver.com/tonet","name":"톤트헤어_미니먼트","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Ftvcast.phinf%2F20250225_183%2Fd8NdW_17404174908170FsRs_JPEG%2Fimage.jpg%22&type=nf40_40&service=navermain"}},"video":{"playTime":"00:42"},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6ccf"},{"@type":"MATERIAL-PC-FEED","title":"그레이와 어울리는 5가지 컬러! 가을 핀터레스트♥","url":"https://in.naver.com/purplemodern/contents/internal/863882364421728","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyNTA5MDZfNDMg%2FMDAxNzU3MTM1NDg3Mzcx.OKbuHE2drmew37DnQYBtfdx3ThlZBDx26368n4g4iR8g.zCNKnK398wvM0bdueN9cCQ_U1stuJ1a04u_Frc8jjwYg.JPEG%2F%EA%B7%B8%EB%A0%88%EC%9D%B4_%EC%BD%94%EB%94%94.jpg%22&type=ff364_236&service=navermain"},"source":{"url":"https://blog.naver.com/purplemodern","name":"리아","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyNDA5MzBfMTEw%2FMDAxNzI3NjkxNDYzNjQy.A5SGDdPiW7sifV4vgHGXZ660eRSxaJwSNPQUsV-OULog.8khb7Sb84ds6fS-E4dOKi_tssfLmw95sZM5RSmLqUBwg.JPEG%2FprofileImage.jpg%22&type=nf40_40&service=navermain"}},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6cd0"},{"@type":"MATERIAL-PC-FEED","title":"워싱과 포켓 위치의 중요성..👌 165cm 58kg 모두 m사이즈 착용 예쁜 와이드핏 완성🤍✨ 저와 같이 허벅지,힙에 살 몰빵된  하체 통통형 분들에게 완전 추천드려요! . . #하비코디#허얇엉큰#허얇골넓#와이드청바지#중청#66사이즈쇼핑몰#체형커버#체형커버#오오티디#가을코디#데일리룩#66사이즈#와이드팬츠#청바지#데님","url":"https://m.blog.naver.com/reepetal/clip/11495036","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Ftvcast.phinf%2F20250904_61%2F8djHB_1756935097673UfkVI_JPEG%2F705C6047-0B54-495F-9042-89A18CD7DDCE.jpg%22&type=ff364_236&service=navermain"},"source":{"url":"https://blog.naver.com/reepetal","name":"뉴리","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogpfthumb.phinf.naver.net%2FMjAyNTA2MTFfMTQ5%2FMDAxNzQ5NjE3MjU0NTk5.UIta2RgsO6_IumswNGZgBRNdJkL4nK0tv9WB3td1p-cg.90Xd0WCcf9ZTz0IyFRZYaaonYjjvByGM1A1sR1MfBqgg.PNG%2FprofileImage.png%22&type=nf40_40&service=navermain"}},"video":{"playTime":"00:08"},"showLiveBadge":false,"_id":"654ad80598c6dbca70ba6cd1"},{"@type":"MATERIAL-PC-FEED","title":"시눈 풀오버니트코디! 25AUTUMN 명동점에서 입어보기!","url":"https://in.naver.com/aengcho/contents/internal/864392723498496","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22http%3A%2F%2Fblogfiles.naver.net%2FMjAyNTA5MDhfMTUg%2FMDAxNzU3MzM0MTI4MTE3.GaGh6waTIQvYgOYlWc9dLkBgqoYsnHMJKEgcK-fJ15gg.AtgUNEk8mTmMVEBMV_Hnts3 ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"b73e7711-8d36-11f0-96c8-3df68a6b888d","@provider":"lambda","@lastModifiedAt":[2025,9,9,4,37,39,97000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250909 13:23:43","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250908 17:55:16","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250909 13:21:38","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181433494.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181453897.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250909 13:09:55","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250909 13:30:33","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250909 09:15:55","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20250909 12:25:39","_id":null,"@type":"PC-N ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"외교장관, 美워싱턴 도착…한국인 300명 석방·재발방지 협의","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015614439","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"李대통령, '권성동 압력의혹' 필리핀 차관사업 \"즉시 중지 명령\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015614423","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec43489"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"鄭, '내란' 26번 외쳤지만 '협치' 침묵…국힘 향해 \"해산될수도\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015614430","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348a"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"장동혁, 정청래 연설에 \"너무 실망…'여의도 대통령' 보는 듯\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015614421","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"해병특검, 군검찰의 박정훈 대령 체포시도 확인…2차례 영장","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015614424","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348c"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'성 비위 내홍' 혁신당, 11일 비대위원장 선출…조국 등판 주목","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015613963","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"683f13f2f74934e40c0fed6b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'공천개입 의혹' 김상민 前검사 김건희특검 출석…\"오해·억측\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015613762","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6878979ea0b3054b67365363"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"KT, 소액결제 관련 사이버 침해 신고…경찰·과기부, 현장조사","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015614428","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6878c912557b0ee3fe1086d6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"구글 \"한국 지도 방위 좌표 뺀다\"…보안시설도 가림 처리","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015614066","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"68b5382ad27bbfaa94489d18"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"조태용 겨눈 내란특검…작 ...
# window["EAGER-DATA"]["PC-PREMIUM-AD"] = {"@type":"PC-PREMIUM-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N010","adlineId":null,"vimp100p0s":null,"assets":null,"vimp50p1s":"https://siape.veta.naver.com/fxview?eu=EU10044434&calp=-&oj=UDLDkoMX9MNQsbHfqBkowoTWeuRr85i%2Bog4lV3Vyj9WvM9wi07acJSGNcbrnFmKn&ac=8206821&src=4733402&evtcd=V900&x_ti=1362&tb=&oid=&sid1=&sid2=&rk=UT5q29fYHFTNKb3g-buPyQ&eltts=7qjBKGUKon2B3qHjBRDDRQ%3D%3D&brs=Y&&eid=V900"},"_id":null,"@type":null,"@code":"PC-PREMIUM-AD","@template":"PC-PREMIUM-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["PC-MYSERVICE-META"] = {"@type":"PC-MYSREVICE-META","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"serviceMetaList":[],"_id":"68414a73a10d30068523e7ee","@type":"MY-SERVICE-META-BLOCK","@code":"PC-MYSERVICE-META","@template":"NONE","@flowId":"PC-MYSERVICE-META","@flowExecutionId":"cd505675-8d36-11f0-8816-930f1a3624c5","@provider":"lambda","@lastModifiedAt":[2025,9,9,4,38,16,184000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"b6382a9c-8d36-11f0-96c8-657dfea70e56","@provider":"lambda","@lastModifiedAt":[2025,9,9,4,37,37,371000000]}
# window["EAGER-DATA"]["PC-HEADLINE-AD"] = {"@type":"PC-HEADLINE-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N402","adlineId":"3053955","vimp100p0s":"https://siape.veta.naver.com/fxview?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FITWeuRr85i%2Bog4lV3Vyj9WvM9wi07acJSGNcbrnFmKn&ac=9177031&src=7781577&evtcd=V900&x_ti=1587&tb=&oid=&sid1=&sid2=&rk=eOiKLQD_lZQVoRyGjpdjWA&eltts=7qjBKGUKon2B3qHjBRDDRQ%3D%3D&brs=Y&&eid=V900","assets":{"hl_web_img":{"url":"https://ssl.pstatic.net/melona/libs/1544/1544905/0da99d422d82b16b5cb2_20250908182322790.png","alt":"[광고]마뗑킴 네이버에서, 네이버 입점 기념 단독 혜택","w":488,"h":216},"hl_web_img_dark":{"url":"https://ssl.pstatic.net/melona/libs/1544/1544905/d2bcb93410e5217b8519_20250908182328832.png","alt":"[광고]마뗑킴 네이버에서, 네이버 입점 기념 단독 혜택","w":488,"h":216},"hl_link":{"url":"https://siape.veta.naver.com/fxclick?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FITWeuRr85i%2Bog4lV3Vyj9WvM9wi07acJSGNcbrnFmKn&ac=9177031&src=7781577&br=4810414&evtcd=P901&x_ti=1587&tb=&oid=&sid1=&sid2=&rk=eOiKLQD_lZQVoRyGjpdjWA&eltts=7qjBKGUKon2B3qHjBRDDRQ%3D%3D&brs=Y&&tr=ndp&a=...","clicktracking":"https://ssl.pstatic.net/tveta/libs/1by1.gif"},"bb_web_img":null,"bb_web_img_dark":null,"bb_link":null,"bb_web_text":null}},"_id":null,"@type":null,"@code":"PC-HEADLINE-AD","@template":"PC-HEADLINE-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"bd6294cd-8d36-11f0-8816-3517d2f5f880","@provider":"lambda","@lastModifiedAt":[2025,9,9,4,37,49,401000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"d66be1f1-8d36-11f0-96c8-9dbe95910f3b","@provider":"lambda","@lastModifiedAt":[2025,9,9,4,38,31,387000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.shpt","name":"쇼핑투데이","id":"PC-MEDIA-SHOPPING-TODAY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2024-04-18T16:13:27.109"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"bfc4a014-8d36-11f0-96c8-1dd2a56e467d","@provider":"lambda","@lastModifiedAt":[2025,9,9,4,37,53,396000000]}
# </script>
# <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.de9c70b5.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/preload.f554ff8a.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/search.3aef6eb8.js?o=www"></script><script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/resources/js/main.67861b24.js?o=www"></script><link href="https://pm.pstatic.net/resources/css/main.f792b019.css" rel="stylesheet"/></link></meta></meta></meta></meta></meta></meta></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div> <script data-gfp-banner-size="830x130" data-gfp-banner-type="full" id="ad-timeboard-response" type="text/plain">{"payload":{"requestId":"2edec58cf767411e85b4d6f31d3f40da","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"lazyRenderMediaFailed":[{"url":"https://tivan.naver.com/sc2/93/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":46,"adDivId":"ad_timeboard","ads":[{"encrypted":"OKirZGNZxx3hhDJv9-oS-JzVRT9La7Y7xnE8jK5YQpVfweTyr6a45iS6QG2whlmojwfhySvLRsJPIDeDRPTptFxyDNyu3ctCzTNnP3MXctJFHZslp1rWSn6vbXqsofbadndEisdxBONjmEXRG9iPLkjdxxa7-lZCg8aSTSk9TMHmCqbpfjH9Qlz-ypoQwFM-YZYqMTxrnckaEfekkBDQz3YeniEVDj2jgdOHTOkp_sLuUWXVdqTykSVUKwJ0xyH1SR-BEfBjT4j06UCqzysNMNS3nk81fw69JRGDv61Th1p1XkMp3tRYXPloKETn4YIr9o8EAO-hNPdsfg5vASLCA7Y0XD9bm94o6LnmFSooctimLt7LADfJx3_-0-fAPo1gCKEF684s-RoebdQYhzqUiX4xGbQPKTQGrV39HEOsL3KaNxgTxVJdkZynuqAcw6Uvlo4kWHQkGuN9hSNAwEgue8czgSpYFaxkQVOJqt2ZmflVoeuOHdfFnXIMh1-EDWZ1TjuERTQlkBabHe8s4FvmeDJ8-NDDTOFKTQXvCNELqcQvk3j74ytQSGjBFz76jA4UA2qmQsVZ35_IDuL0cZ_KecaY4MrSDlcfqXjMh-P0pozllRVp3tRsHQ1y0xzKJd-EYFD_V6SC_xVEz5bu80CYivGE4_Etm6vSN0xyMpB_KHtzg6iROjsHJVajXjt0KJvlmodLYKjJyfiQfxYk88srXQ==","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5O8Pu%2Bk9n1yQmy2RH7UYUvGpaZuIPxM%2BWTZqkKRSCIRXddERvSZYD%2F1JL1qM2Pf%2FamE1nrka%2FOYvqIOJVd1co%2FVrzPcItO2nCWeBJzbEUemkkplqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvb10wXXPTxP9fUvtBMhB%2F95FF8ugsnigZsy9gvmfFyhM0\u0026ac=9176874\u0026src=7781087\u0026evtcd=BID_WIN\u0026x_ti=1505\u0026rk=nczIgXpg9DuDAbKHC-6XQw\u0026eltts=7qjBKGUKon2B3qHjBRDDRQ%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[],"priv":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","cid":"1525467","crid":"2787424","exp":1259,"adContext":"{\"id\":\"2edec58cf767411e85b4d6f31d3f40da\",\"impId\":\"BR0_I0\",\"adProviderName\":\"NDP_SF\",\"cid\":[\"1525467\"],\"crid\":[\"2787424\"],\"c ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div class="header_inner" id="topSearchWrap"> <div class="search_special_bg" id="special-logo"></div> <div class="ad_area" id="timeboard-ex" style="width:1280px"> </div> <div class="search_area" id="search_area" style="border-color:#fff"> <div class="search_group"> <div class="search_group_inner" id="search"> <h1 class="search_logo" id="special-input-logo"></h1> <form action="https://search.naver.com/search.naver" id="sform" method="get" name="search" role="search"> <fieldset> <legend class="blind">검색</legend> <input name="where" type="hidden" value="nexearch"/> <input id="sm" name="sm" type="hidden" value="top_hty"/> <input id="fbm" name="fbm" type="hidden" value="0"/> <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/> <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/> <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/> <input id="ie" name="ie" type="hidden" value="utf8"/> <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/> <input disabled="disabled" id="os" name="os" type="hidden" value=""/> <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/> <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/> <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/> <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/> <div class="search_input_box"> <input aria-activedescendant="" aria-autocomplete="list" aria-controls="" aria-expanded="false" aria-haspopup="listbox" aria-owns="autoFrame" autocomplete="off" class="search_input" data-atcmp-element="" id="query" maxlength="255" name="query" placeholder="검색어를 입력해 주세요." role="combobox" title="검색어를 입력해 주세요." type="search"/> </div> <button class="btn_search" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})' type="submit"> <span class="ico_btn_search_svg"> <svg id="search-btn" viewbox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"></path> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button aria-pressed="false" class="btn_keyboard" id="ke_kbd_btn" type="button"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button class="btn_arrow" data-atcmp-element="" id="nautocomplete" type="button"> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right"></div> <div aria-label="주요 서비스" class="shortcut_area" id="shortcutArea" role="navigation"></div> <div class="menu_area" id="topAsideArea"></div> <div class="pay_area" id="topPayArea"></div> <div class="talk_area" id="topTalkArea"></div> <div class="notify_area" id="topNotiArea"></div> <div class="shopping_area" id="topShoppingArea"></div> </div> </div> <div id="container" role="main"> <div class="ad_premium_area" id="ad_premium_area" style="min-width:1920px"> </div> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div> <script> window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20250909133859',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),l=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(l&&l.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),l&&l.setAttribute("class","ico_btn_search type_color"),l&&l.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var l=Math.floor(Math.random()*e.items.length),s=e.items[l];e.items=[s];const o=s&&s.content?s.content.input:null;t(o&&o.color);const i=document.getElementById("search"),n=i&&(!o||!o.showSearchLogo);n&&i.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?n&&i.classList.remove("type_special_logo_full"):n&&i.classList.add("type_special_logo_full")});var r=o&&o.placeholder;if(r){var a=document.getElementById("query");a&&r&&a.setAttribute("title",r),a&&r&&a.setAttribute("placeholder",r)}}()</script> <script>!function(){try{-1!==window.navigator.userAgent.indexOf("Edg/140.0")&&window.addEventListener("load",function(){setTimeout(function(){""===document.getElementById("topAsideArea").innerHTML&&window.alert('긴급 점검 안내\n\n현재 엣지 브라우저 일부 버전에서 네이버 메인에 접속되지 않는 현상이 확인되어 긴급 점검 중입니다.\n\n※ 임시해결방법\nEdge 브라우저 설정 → 개인정보 → 추적방지 → ’엄격’ 설정을"기본 or 밸런스"로 변경시 정상 접속 가능\n또는\n엣지 브라우저 외 다른 브라우저(크롬, 웨일 등) 사용\n\n최대한 빨리 정상화 될 수 있도록 최선을 다하겠습니다.\n서비스 이용에 불편을 드려 죄송합니다.')},1e3)})}catch(n){console.error(n)}}()</script> </body> </html>

# %% [markdown]
# - 태그의 이름을 기준으로 검색
#     - soup.태그명 -> 해당 html 문서에서 해당 태그의 첫 번째 태그를 되돌려준다.
#     - soup.태그명.string -> 첫 번째 태그에서 contents(태그 안에 데이터)를 되돌려준다.
#         - ex)`<p>text data</p>`-> test data 출력
#     - soup.태그명['속성명] -> 첫 번째 태그에서 특정 속성의 값을 되돌려준다.
#         - ex) `<a href = 'https://www.google.com'>google</a>` -> 'https://www.google.com' 출력

# %%
soup.a
# a태그는 하이퍼링크
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>

# %%
soup.a.string
# Out:
# '상단영역 바로가기'

# %%
soup.a['href']
# Out:
# '#topAsideButton'

# %% [markdown]
# - find()
#     - html 데이터에서 특정 태그의 첫번째 정보를 출력
#     - find(속성명 = 속성값) : 태그들 중에 특정 속성의 특정한 값을 가진 태그의 첫 번째 정보를 출력
#     - 함수의 결과의 타입은 TAG 데이터의 타입으로 되돌려준다.
# - find_all()
#     - html 데이터에서 특정 태그의 모든 정보를 출력
#     - limit 매개변수 : 찾는 태그의 개수를 지정
#     - 햠수의 결과의 타입은 TAG 데이터들이 모인 ResultSet 타입으로 되돌려준다. (find(), find_all() 함수를 사용하려면 TAG 데이터 타입으로 데이터를 추출하여 사용)

# %%
type(soup)
soup
# Out:
# <html lang="ko">
# <head>
# <title>네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title">
# <meta content="네이버페이 증권" property="og:title">
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="https://finance.naver.com" property="og:url"/>
# <meta content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250828144601/css/finance_header.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250828144601/css/finance.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20250828144601/css/newstock3.css" rel="stylesheet" type="text/css"/>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20250828144601/js/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20250828144601/js/release/common.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20250828144601/js/jindoComponent/jindo.Component.1.0.3.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20250828144601/js/nhn.autocomplete.stock.js" type="text/javascript"></script>
# <script>
# 	var ieVersion = (function () {
#         var version = -1;
#         if (
#           navigator.appName == 'Microsoft Internet Explorer' &&
#           navigator.userAgent.toLowerCase().indexOf('msie') != -1 &&
#           new RegExp('MSIE ([0-9]{1,}[\./0-9]{0,})').exec(navigator.userAgent) != null
#         ) {
#           version = parseInt(RegExp.$1);
#         }
#         return version;
#       })();
# </script>
# <!-- smart channel 광고 -->
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
# </script>
# <script type="text/javascript">
# 		(function(){
# 			if (ieVersion === -1 || ieVersion > 10) {
# 				window.gladsdk = window.gladsdk || { cmd: [] };
#
# 				gladsdk.cmd.push(function() {
# 						gladsdk.defineAdSlot({
# 							adUnitId: "p_new_stock",
# 							adSlotElementId: "_SmartChannelTopBanner",
# 							uct: "KR",
# 							customParam: {
# 								calp:
#
#
#
#
#
#
# 									"home"
# 							},
# 						});
#
# 						gladsdk.addEventListener(gladsdk.event.AD_LOADED, function(ad) {
# 							//console.log(gladsdk.event.AD_LOADED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.AD_CLICKED, function(ad) {
# 							//console.log(gladsdk.event.AD_CLICKED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.AD_IMPRESSED, function(ad) {
# 							//console.log(gladsdk.event.AD_IMPRESSED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.ERROR, function(ad, error) {
# 							//TODO: 오류 로깅처리
# 							//console.log(gladsdk.event.ERROR);
# 						});
# 					});
# 			}
# 		})();
# 	</script>
# <link href="https://ssl.pstatic.net/imgstock/favi/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
#     (function(){
# 		document.write(
# 				[
# 					'<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/imgstock/favi/favicon-180x180.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>',
# 					'<link rel="icon" type="image/png" sizes="16x16" href="https://ssl.pstatic.net/imgstock/favi/favicon-16x16.png"/>',
# 					'<link rel="icon" type="image/png" sizes="32x32" href="https://ssl.pstatic.net/imgstock/favi/favicon-32x32.png"/>',
# 					'<link rel="icon" type="image/png" sizes="96x96" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="icon" type="image/png" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>'
# 				]
# 			.join('\n')
# 		);
#     })();
#     </script>
# </meta></meta></head>
# <body onload="getGNB();">
# <script type="text/javascript">
#
#
#
#
#
#
#
# var nsc="finance.home";
#
#
# var ccsrv="cc.naver.com";
#
#
#
#
# 	var gnb_service='finance';
#
#
#
# var gnb_logout=document.URL; //GNB에서 로그아웃 후 redirect 될 URL
# var gnb_searchbox='off'; //미니 검색창을 on 할지 off 할지. default는 off
# var gnb_shortnick='off'; //닉네임 말줄임(10자)을 on할지 off 할지. default는 off.
#
#
# var gnb_naverme_layer_open_callback = function(){
# 	   var naverLayerSize = gnbNaverMeLayer.getLayerSize();
#
# 		var me_layers = document.getElementById("me_layers");
# 		me_layers.width=naverLayerSize.width;
# 		me_layers.height=naverLayerSize.height;};
#
# var gnb_naverme_layer_close_callback = function(){
#
# 			var me_layers = document.getElementById("me_layers");
# 			me_layers.width="0";
# 			me_layers.height="0";};
# </script>
# <div id="u_skip">
# <a href="#menu" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#start" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div id="header">
# <div class="header_area">
# <div class="header_inner">
# <div class="logo_area">
# <h1 class="service">
# <a class="logo_link" href="https://www.naver.com/" onclick="clickcr(this, 'STA.naver', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 22 22" width="22" xmlns="http://www.w3.org/2000/svg">
# <path d="M22 11C22 13.1756 21.3549 15.3023 20.1462 17.1113C18.9375 18.9202 17.2195 20.3301 15.2095 21.1627C13.1995 21.9952 10.9878 22.2131 8.85401 21.7886C6.72022 21.3642 4.76021 20.3166 3.22183 18.7782C1.68345 17.2398 0.635805 15.2798 0.211368 13.146C-0.213069 11.0122 0.00476298 8.80047 0.837327 6.79048C1.66989 4.78049 3.07979 3.06253 4.88873 1.85383C6.69768 0.645137 8.82441 0 11 0C13.9174 0 16.7153 1.15893 18.7782 3.22183C20.8411 5.28473 22 8.08262 22 11ZM12.8398 5.83V11.3602L8.98976 5.83H5.83V16.1838H9.1575V10.637L13.0075 16.17H16.1783V5.83H12.8398Z" fill="#000"></path>
# </svg>
# <span class="blind">네이버</span>
# </a>
# <a class="logo_link" href="https://new-m.pay.naver.com/" onclick="clickcr(this, 'STA.pay', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 37 22" width="37" xmlns="http://www.w3.org/2000/svg">
# <path d="M34.4319 5.21944L31.3913 12.1478L27.9518 5.21944H25.3072L30.1783 14.8317L28.1703 19.3358H30.7384L37 5.2331L34.4319 5.21944ZM23.6171 15.9331H21.1037V14.9328C20.1894 15.7342 19.0108 16.1685 17.7953 16.1518C14.7901 16.1518 12.4379 13.692 12.4379 10.5763C12.4379 7.46057 14.7874 5.00079 17.7953 5.00079C19.0104 4.9833 20.189 5.41657 21.1037 6.21701V5.21944H23.6171V15.9331ZM21.3987 10.5899C21.3987 8.57019 19.9891 7.03694 18.1204 7.03694C16.2517 7.03694 14.842 8.57019 14.842 10.5899C14.842 12.6097 16.249 14.1429 18.1204 14.1429C19.9918 14.1429 21.3987 12.596 21.3987 10.5899ZM0.00819554 19.3358H2.63088V15.023C3.52823 15.7695 4.66309 16.1699 5.83001 16.1518C8.83516 16.1518 11.1901 13.692 11.1901 10.5763C11.1901 7.46057 8.83789 5.00079 5.83001 5.00079C4.61166 4.9789 3.42899 5.4126 2.51341 6.21701V5.21944H0L0.00819554 19.3358ZM5.51856 7.03694C7.38722 7.03694 8.79691 8.57019 8.79691 10.5899C8.79691 12.6097 7.38722 14.1429 5.51856 14.1429C3.6499 14.1429 2.24021 12.6097 2.24021 10.5899C2.24021 8.57019 3.63351 7.03694 5.51856 7.03694Z" fill="#000"></path>
# </svg>
# <span class="blind">페이</span>
# </a>
# <a class="logo_link" href="/" onclick="clickcr(this, 'STA.finance', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 34 22" width="34" xmlns="http://www.w3.org/2000/svg">
# <path d="M2.43006 8.88998L1.85406 6.99998C5.29206 6.31598 7.00206 5.34398 7.45206 4.31798H2.71806V2.35598H14.3641V4.31798H9.75606C9.70206 4.65998 9.61206 4.98398 9.46806 5.28998L15.2101 6.98198L14.4901 8.88998L8.02806 6.92798C6.84006 7.75598 5.00406 8.40398 2.43006 8.88998ZM0.612061 11.5V9.53798H16.4521V11.5H0.612061ZM6.53406 12.796H10.5301C13.2301 12.796 14.7961 14.128 14.7961 15.91C14.7961 17.71 13.2301 19.024 10.5301 19.024H6.53406C3.85206 19.024 2.28606 17.71 2.28606 15.91C2.28606 14.128 3.85206 12.796 6.53406 12.796ZM6.96606 17.044H10.1161C11.7901 17.044 12.4921 16.594 12.4921 15.892C12.4921 15.19 11.7901 14.776 10.1161 14.776H6.96606C5.29206 14.776 4.57206 15.19 4.57206 15.892C4.57206 16.594 5.29206 17.044 6.96606 17.044Z" fill="#000"></path>
# <path d="M25.1904 13.354V11.536H29.4564V2.03198H31.7604V15.334H29.4564V13.354H25.1904ZM21.3384 10.564C20.9244 10.582 20.5464 10.582 20.1684 10.582H17.4504L17.3604 8.61998H20.3844C21.5004 8.61998 22.9584 8.56598 24.4884 8.45798C24.7224 6.99998 24.8484 5.63198 24.8664 4.62398H18.4404V2.66198H27.0984V3.56198C27.0984 5.16398 26.9724 6.76598 26.7564 8.25998L28.2684 8.09798L28.5024 10.006C26.9724 10.222 25.2264 10.384 23.5704 10.474C23.4984 11.5 23.3904 12.562 23.2644 13.714L21.0684 13.588C21.1764 12.508 21.2664 11.536 21.3384 10.564ZM22.4724 14.254V16.756H32.3724V18.844H20.1684V14.254H22.4724Z" fill="#000"></path>
# </svg>
# <span class="blind">증권</span>
# </a>
# </h1>
# </div>
# <div class="right_area">
# <div class="search_area">
# <form action="/search/search.naver" method="get" name="search" onsubmit="return delayed_submit(this)" style="margin:0; padding:0;">
# <label class="blind" for="stock_items">증권 종목명·지수명 검색</label>
# <input accesskey="s" autocomplete="off" class="search_input" id="stock_items" name="query" placeholder="종목명·지수명 입력" title="종목명·지수명 검색" type="text"/>
# <input id="_endUrl" name="endUrl" type="hidden" value="">
# <button class="search_button" onclick="clickcr(this, 'STA.search', '', '', event);" type="submit">
# <svg fill="none" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M6.9999 2.59996C4.56985 2.59996 2.5999 4.56991 2.5999 6.99996C2.5999 9.43002 4.56985 11.4 6.9999 11.4C9.42996 11.4 11.3999 9.43002 11.3999 6.99996C11.3999 4.56991 9.42996 2.59996 6.9999 2.59996ZM1.3999 6.99996C1.3999 3.90717 3.90711 1.39996 6.9999 1.39996C10.0927 1.39996 12.5999 3.90717 12.5999 6.99996C12.5999 10.0928 10.0927 12.6 6.9999 12.6C3.90711 12.6 1.3999 10.0928 1.3999 6.99996Z" fill="#404048" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M10.2421 10.2424C10.4765 10.0081 10.8564 10.0081 11.0907 10.2424L14.424 13.5758C14.6583 13.8101 14.6583 14.19 14.424 14.4243C14.1897 14.6586 13.8098 14.6586 13.5755 14.4243L10.2421 11.091C10.0078 10.8567 10.0078 10.4768 10.2421 10.2424Z" fill="#404048" fill-rule="evenodd"></path>
# </svg>
# <span class="blind">검색</span>
# </button>
# <div class="auto_area">
# <span class="blind">자동완성</span>
# <div id="autoFrame" style="display: none;">
# <div class="wrap" id="atcmp" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <ul class="_resultBox">
# <li>
# <a class="_au_real_list" href="#" onclick="clickcr(this, 'AUT.list', '', '', event); return false;">
# <span class="num _au_real_list">@code@</span>
# <span class="_au_real_list">@txt@</span>
# <span class="type _au_real_list">@market@</span>
# </a>
# <div class="_au_full" style="display:none">@full_txt@</div>
# <div class="_au_code" style="display:none">@in_code@</div>
# <div class="_au_name" style="display:none">@in_name@</div>
# <div class="_au_link" style="display:none">@in_link@</div>
# <div class="_au_market" style="display:none">@in_market@</div>
# </li>
# </ul>
# <div class="search_notice">
# <p class="text">
# 												공모주와 해외 종목은 모바일 페이지로 이동합니다.
# 											</p>
# </div>
# </div>
# </div>
# <!-- 현재 자동완성 기능을 사용하고 계십니다 -->
# <div class="wrap" id="atcmpIng" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <p class="msg">
# 												현재 자동완성 기능을 사용하고 계십니다.
# 											</p>
# </div>
# </div>
# </div>
# <!--// 현재 자동완성 기능을 사용하고 계십니다 -->
# <!-- 자동완성 기능이 활성화 -->
# <div class="wrap" id="atcmpStart" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <p class="msg">
# 												자동완성 기능이 활성화되었습니다.
# 											</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </input></form>
# </div>
# <div class="gnb_area">
# <div id="gnb">
# <script charset="EUC-KR" type="text/javascript">
# 							var gnb_service = "finance";
# 							var gnb_template = location.protocol === "http:" ? "gnb_quirks_euckr" : "gnb_utf8" ;
# 							var gnb_logout=encodeURIComponent(location.href);
# 							var gnb_brightness = 1;
# 							var gnb_one_naver = 0;
# 						</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20250909" type="text/javascript">
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div id="menu">
# <ul class="menu">
# <li class="m1 first on"><a href="/" onclick="clickcr(this, 'LNB.home', '', '', event);"><span class="tx">증권 홈</span><span class="blind">선택됨</span></a></li>
# <li class="m2"><a href="/sise/" onclick="clickcr(this, 'LNB.sise', '', '', event);"><span class="tx">국내증시</span></a></li>
# <li class="m3"><a href="/world/" onclick="clickcr(this, 'LNB.world', '', '', event);"><span class="tx">해외증시</span></a></li>
# <li class="m4"><a href="/marketindex/" onclick="clickcr(this, 'LNB.market', '', '', event);"><span class="tx">시장지표</span></a></li>
# <li class="m6"><a href="/research/" onclick="clickcr(this, 'LNB.research', '', '', event);"><span class="tx">리서치</span></a></li>
# <li class="m7"><a href="/news/"><span class="tx">뉴스</span></a></li>
# <li class="m8"><a href="/mystock/" onclick="clickcr(this, 'LNB.mystock', '', '', event);"><span class="tx">MY</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <script type="text/JavaScript">
# 		/* lcs 집계 */
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
#
# 		/* 검색 자동완성 [ 인자1 : 검색input의 ID, 인자2 : iframe 태그 ID ]   */
# 		// AutoComplete 생성
# 		var acDomain = "ac.stock.naver.com";
# 		if (location.hostname.indexOf("staging-") > -1) {
# 			acDomain = "staging-" + acDomain;
# 		} else if (location.hostname.indexOf("test-") > -1) {
# 			acDomain = "test-" + acDomain;
# 		} else if (location.hostname.indexOf("dev-") > -1 || location.hostname.indexOf("localhost") > -1 || location.hostname.indexOf("local-") > -1) {
# 			acDomain = "dev-" + acDomain;
# 		}
#
#         var acUrl = "https://" + acDomain + "/ac";
#
# 		smartSearch = new nhn.Autocomplete(
# 			// InputManager 생성
# 			new nhn.AcInputManager(jindo.$("stock_items")),
# 			// DataManager 생성
# 			new nhn.AcDataManager(acUrl, "xhr", "get", {}),
# 			// ViewManager 생성
# 			new nhn.AcStockViewManager(jindo.$("autoFrame"), jindo.$("nautocomplete"), {
#                                         strMax: 200,
#                                         listMax: [7, 2, 2],
#                                         aRedirectUrl: [
# 										"https://" + window.location.hostname,
#                             			"https://finance.naver.com",
#                             			"https://finance.naver.com"],
# 										mobileUrl: "https://m.stock.naver.com"}),
# 			// Autocomplete Option
#             {formId:"search", cookieDomain:location.hostname, cookieName:"NaverCommonStock_disable"});
#
# 			smartSearch.attach({
# 	            onFocus: function () {
# 	                var weInput = jindo.$Element('stock_items');
# 	                if (weInput && weInput.hasClass("snb_default")) {
# 	                        weInput.text("");
# 	                        weInput.removeClass('snb_default');
# 	                }
# 	            }
# 	        });
#
# 		/* 통합검색  start ----->  */
# 		var sSearchHintText = '종목명·지수명·환율명·원자재명 입력';
# 		function itegrationSearch() {
# 			var query = jindo.$('stock_items').value;
#
# 			if ( query == ''  || encodeURIComponent(query) == encodeURIComponent(sSearchHintText))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
#
#             var url = "https://search.naver.com/search.naver?sm=sta_hty.finance&where=nexearch&ie=UTF8&query=" + encodeURIComponent(query);
#             window.open(url, "_blank");
#
# 			return false;
# 		}
#
# 		function delayed_submit(object) {
# 			if (navigator.userAgent.indexOf('MSIE') == -1) {
# 				window.setTimeout(function() {stock_search(object)}, 300);
# 			} else {
# 				stock_search(object);
# 			}
# 			return false;
# 		}
#
# 		function stock_search (object) {
# 			// endUrl check
# 			if (object.endUrl.value) {
# 				if (object.endUrl.value.startsWith("https://m.stock.naver.com")) {
# 					// 검색정보 초기화
# 					var _endUrl = object.endUrl.value;
# 					object.query.value = "";
# 					object.endUrl.value = "";
# 					document.getElementById("atcmp").style.display="none";
# 					window.open(_endUrl, "_blank");
# 				} else {
# 					location.href = object.endUrl.value;
# 				}
#
# 				return;
# 			}
#
# 			// query check
# 			query = object.query.value.replace(/^\s*/,'').replace(/\s*$/,'');	// trim
# 			object.query.value=query;
#
# 			if ( query == '' || query == sSearchHintText.replace(/^\s*/,'').replace(/\s*$/,''))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
# 			else {
# 				object.submit();
# 			}
# 		}
# 		/* <---------- 통합검색  end */
#
# 		function popup()
# 		{
# 			win = window.open('/template/group_limit_pop.jsp','finan_popup','width=569 height=278 scrollbars=no status=no');
# 			win.focus();
# 		}
# 	</script>
# <iframe frameborder="0" height="0" id="me_layers" name="test" scrolling="no" style="display:block;top: 22px; right: 209px; position: absolute; z-index: 15;" title="네이버미 영역" width="0"></iframe>
# </div>
# <div id="wrap">
# <hr/>
# <div class="blind" id="start"><strong name="start">본문시작</strong></div>
# <dl class="blind">
# <dt>오늘의 코스피/코스닥 지수</dt>
# <dd>2025년 09월 09일 장중</dd>
# <dd>코스피 지수 3,254.81 전일대비 상승 35.22 플러스 1.09 퍼센트</dd>
# <dd>코스닥 지수 822.37 전일대비 상승 3.77 플러스 0.46 퍼센트</dd>
# </dl>
# <div class="home_spot view_on">
# <div class="bx_spot">
# <div class="tab_spot tab2" id="tab_search">
# <ul>
# <li><a href="#" onclick="javascript:showMainRecentMyStockSearchStock('tab_search', 'tab_spot tab1', '000000', 'recent');clickcr(this, 'mys.recent', '', '', event);return false;"><span>최근조회종목</span></a></li>
# <li><a href="#" onclick="javascript:showMainRecentMyStockSearchStock('tab_search', 'tab_spot tab2', '000000', 'mystock');clickcr(this, 'mys.interest', '', '', event);return false;"><span>MY STOCK</span></a></li>
# </ul>
# </div>
# <div class="section_tab" id="recent_search_tab">
# <strong class="blind" id="recent_mystock_blind">최근 조회종목 리스트</strong>
# <ul class="tab_list">
# </ul>
# </div>
# <input alt="닫기" class="btn_spot" onclick="clickcr(this, (jindo.$Element('tab_search').hasClass('tab1') ? 'mys*r.close' : 'mys*i.close'), '', '', event);" src="https://ssl.pstatic.net/static/nfinance/btn_spot_close.gif" style="display:none" type="image"/>
# <input alt="펼치기" class="btn_spot" onclick="clickcr(this, (jindo.$Element('tab_search').hasClass('tab1') ? 'mys*r.open' : 'mys*i.open'), '', '', event);" src="https://ssl.pstatic.net/static/nfinance/btn_spot_open.gif" style="display:none" type="image"/>
# </div>
# </div>
# <div class="home" id="container">
# <div id="content">
# <div class="article">
# <div class="section">
# <div class="news_area _replaceNewsLink">
# <div class="section_strategy">
# <h2 class="h_strategy"><span>주요뉴스</span></h2>
# <ul>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=014&amp;article_id=0005403882" onclick="clickcr(this, 'tdn.list', '014_0005403882', '0', event);">1억 넣으면 월 150만원 준다더니..."ETF 기준가도 꼭 살피세요"</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=015&amp;article_id=0005182328" onclick="clickcr(this, 'tdn.list', '015_0005182328', '1', event);">'곧 터진다' 역대급 공매도 폭탄 '째깍째깍'…개미들 '공포'</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=277&amp;article_id=0005649158" onclick="clickcr(this, 'tdn.list', '277_0005649158', '2', event);">"기준가 확인하고 유튜브 맹신 말아야" 금감원, ETF 투자 유의사항 공개</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=008&amp;article_id=0005247676" onclick="clickcr(this, 'tdn.list', '008_0005247676', '3', event);">"1억 넣으면 월 150만원 따박따박?" ETF 분배율의 진실은</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=001&amp;article_id=0015614365" onclick="clickcr(this, 'tdn.list', '001_0015614365', '4', event);">트럼프 차남 "美 따라 가상자산에 뛰어들라…韓, 아시아 선두"</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=003&amp;article_id=0013469922" onclick="clickcr(this, 'tdn.list', '003_0013469922', '5', event);">증시 횡보장에…공매도 투자자 수익률 '반타작'</a></span>
# </li>
# </ul>
# <a class="btn_more" href="/news/mainnews.naver" onclick="clickcr(this, 'tdn.more', '', '', event);"><em class="btn_more4"><span class="blind">주요뉴스 더보기</span></em></a>
# </div>
# </div>
# <div class="section_sise_top">
# <h2 class="h_type"><span>TOP 종목</span></h2>
# <!-- KRX, NXT 탭 -->
# <div class="area_tab_type">
# <ul class="top_tab_list">
# <!-- [D] 선택된 탭 'is_active' -->
# <li class="top_tab_item top_tab_krx is_active">
# <a class="top_tab_link" href="#" onclick="clickcr(this, 'top.krx', '', '', event);return false;">KRX</a>
# </li>
# <li class="top_tab_item top_tab_nxt">
# <a class="top_tab_link" href="#" onclick="clickcr(this, 'top.nxt', '', '', event);return false;">NXT</a>
# </li>
# </ul>
# <div class="text_nxt">
#                                 넥스트레이드(NXT)
#                                 <button class="buttton_tooltip" type="button">
# <span class="icon">
# <span class="blind">도움말</span>
# </span>
# </button>
# <div class="area_tooltip">
# <p>
# <strong>넥스트레이드(NXT)</strong>
#                                         넥스트레이드(NXT)란 대한민국
#                                         최초의 대체거래소(ATS,
#                                         Alternative Trading
#                                         System)입니다. 아래는
#                                         넥스트레이드에서 거래가 가능한
#                                         종목들입니다.
#                                     </p>
# <span class="arrow"></span>
# </div>
# </div>
# </div>
# <!-- //KRX, NXT 탭 -->
# <ul class="tab_sort_list">
# <!-- [D] 선택된 탭 'is_active' -->
# <li class="tab_sort_item is_active"><a class="link tab_sort_sale" href="#" onclick="clickcr(this, 'spe.sale', '', '', event);return false;"><span class="tab1"><span class="blind">거래상위</span></span></a></li>
# <li class="tab_sort_item"><a class="link tab_sort_ceiling" href="#" onclick="clickcr(this, 'spe.ceiling', '', '', event);return false;"><span class="tab2"><span class="blind">상승</span></span></a></li>
# <li class="tab_sort_item"><a class="link tab_sort_bottom" href="#" onclick="clickcr(this, 'spe.bottom', '', '', event);return false;"><span class="tab3"><span class="blind">하락</span></span></a></li>
# <li class="tab_sort_item"><a class="link tab_sort_value" href="#" onclick="clickcr(this, 'spe.value', '', '', event);return false;"><span class="tab4"><span class="blind">시가총액 상위</span></span></a></li>
# </ul>
# <div class="group_type krx_group_type tab1 is_active">
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems1">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>1,248</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 31</td>
# <td>
# <em class="down">
# 				-2.42%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=096040" onclick="clickcr(this, 'spe.slist', '096040', '2', event);">이트론</a></th>
# <td>5</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 5</td>
# <td>
# <em class="down">
# 				-50.00%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=085310" onclick="clickcr(this, 'spe.slist', '085310', '3', event);">엔케이</a></th>
# <td>1,393</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3</td>
# <td>
# <em class="up">
# 				+0.22%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=413630" onclick="clickcr(this, 'spe.slist', '413630', '4', event);">씨피시스템</a></th>
# <td>2,540</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 130</td>
# <td>
# <em class="up">
# 				+5.39%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=044180" onclick="clickcr(this, 'spe.slist', '044180', '5', event);">KD</a></th>
# <td>934</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 167</td>
# <td>
# <em class="up">
# 				+21.77%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006910" onclick="clickcr(this, 'spe.slist', '006910', '6', event);">보성파워텍</a></th>
# <td>4,310</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 355</td>
# <td>
# <em class="up">
# 				+8.98%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=093230" onclick="clickcr(this, 'spe.slist', '093230', '7', event);">이아이디</a></th>
# <td>83</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 19</td>
# <td>
# <em class="down">
# 				-18.63%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=114800" onclick="clickcr(this, 'spe.slist', '114800', '8', event);">KODEX 인버스</a></th>
# <td>3,412</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 48</td>
# <td>
# <em class="down">
# 				-1.39%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=025550" onclick="clickcr(this, 'spe.slist', '025550', '9', event);">한국선재</a></th>
# <td>4,280</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 360</td>
# <td>
# <em class="up">
# 				+9.18%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=333430" onclick="clickcr(this, 'spe.slist', '333430', '10', event);">일승</a></th>
# <td>8,140</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,610</td>
# <td>
# <em class="up">
# 				+24.66%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=462330" onclick="clickcr(this, 'spe.slist', '462330', '11', event);">KODEX 2차전지산업레버리지</a></th>
# <td>1,021</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 21</td>
# <td>
# <em class="up">
# 				+2.10%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=096350" onclick="clickcr(this, 'spe.slist', '096350', '12', event);">대창솔루션</a></th>
# <td>511</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 20</td>
# <td>
# <em class="up">
# 				+4.07%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=024810" onclick="clickcr(this, 'spe.slist', '024810', '13', event);">이화전기</a></th>
# <td>319</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 24</td>
# <td>
# <em class="up">
# 				+8.14%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=201490" onclick="clickcr(this, 'spe.slist', '201490', '14', event);">미투온</a></th>
# <td>6,400</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 600</td>
# <td>
# <em class="up">
# 				+10.34%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=001290" onclick="clickcr(this, 'spe.slist', '001290', '15', event);">상상인증권</a></th>
# <td>845</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 164</td>
# <td>
# <em class="up">
# 				+24.08%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_quant.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">거래상위 더보기</span></em></a>
# </div>
# <div class="group_type nxt_group_type tab1 is_active" style="display:none">
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="nxt_topItems1">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=014940" onclick="clickcr(this, 'spe.slist', '014940', '1', event);">오리엔탈정공</a></th>
# <td>11,320</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 420</td>
# <td>
# <em class="up">
# 				+3.85%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=030530" onclick="clickcr(this, 'spe.slist', '030530', '2', event);">원익홀딩스</a></th>
# <td>11,400</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,060</td>
# <td>
# <em class="up">
# 				+22.06%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=437730" onclick="clickcr(this, 'spe.slist', '437730', '3', event);">삼현</a></th>
# <td>17,320</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,450</td>
# <td>
# <em class="up">
# 				+16.48%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=075580" onclick="clickcr(this, 'spe.slist', '075580', '4', event);">세진중공업</a></th>
# <td>22,050</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 1,450</td>
# <td>
# <em class="down">
# 				-6.17%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=253590" onclick="clickcr(this, 'spe.slist', '253590', '5', event);">네오셈</a></th>
# <td>9,120</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 700</td>
# <td>
# <em class="up">
# 				+8.31%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=067310" onclick="clickcr(this, 'spe.slist', '067310', '6', event);">하나마이크론</a></th>
# <td>15,670</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,650</td>
# <td>
# <em class="up">
# 				+11.77%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006800" onclick="clickcr(this, 'spe.slist', '006800', '7', event);">미래에셋증권</a></th>
# <td>21,600</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,900</td>
# <td>
# <em class="up">
# 				+9.64%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=034020" onclick="clickcr(this, 'spe.slist', '034020', '8', event);">두산에너빌리티</a></th>
# <td>62,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,100</td>
# <td>
# <em class="up">
# 				+1.81%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=452280" onclick="clickcr(this, 'spe.slist', '452280', '9', event);">한선엔지니어링</a></th>
# <td>8,630</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 460</td>
# <td>
# <em class="up">
# 				+5.63%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005930" onclick="clickcr(this, 'spe.slist', '005930', '10', event);">삼성전자</a></th>
# <td>71,100</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,000</td>
# <td>
# <em class="up">
# 				+1.43%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=010140" onclick="clickcr(this, 'spe.slist', '010140', '11', event);">삼성중공업</a></th>
# <td>20,950</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 300</td>
# <td>
# <em class="down">
# 				-1.41%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=059210" onclick="clickcr(this, 'spe.slist', '059210', '12', event);">메타바이오메드</a></th>
# <td>6,340</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 60</td>
# <td>
# <em class="down">
# 				-0.94%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=290650" onclick="clickcr(this, 'spe.slist', '290650', '13', event);">엘앤씨바이오</a></th>
# <td>50,700</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,750</td>
# <td>
# <em class="up">
# 				+3.58%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=080220" onclick="clickcr(this, 'spe.slist', '080220', '14', event);">제주반도체</a></th>
# <td>18,060</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 350</td>
# <td>
# <em class="up">
# 				+1.98%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=0008Z0" onclick="clickcr(this, 'spe.slist', '0008Z0', '15', event);">에스엔시스</a></th>
# <td>48,700</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 2,500</td>
# <td>
# <em class="down">
# 				-4.88%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/nxt_sise_quant.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">거래상위 더보기</span></em></a>
# </div>
# <div class="group_type krx_group_type tab2">
# <table class="tbl_home">
# <caption>상승 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems2">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=023790" onclick="clickcr(this, 'spe.clist', '023790', '1', event);">동일스틸럭스</a></th>
# <td>3,640</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 840 </td>
# <td>
# <em class="up">
# 				+30.00%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=049180" onclick="clickcr(this, 'spe.clist', '049180', '2', event);">셀루메드</a></th>
# <td>802</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 185 </td>
# <td>
# <em class="up">
# 				+29.98%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=066900" onclick="clickcr(this, 'spe.clist', '066900', '3', event);">디에이피</a></th>
# <td>2,510</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 578 </td>
# <td>
# <em class="up">
# 				+29.92%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=333430" onclick="clickcr(this, 'spe.clist', '333430', '4', event);">일승</a></th>
# <td>8,140</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,610 </td>
# <td>
# <em class="up">
# 				+24.66%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=001290" onclick="clickcr(this, 'spe.clist', '001290', '5', event);">상상인증권</a></th>
# <td>845</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 164 </td>
# <td>
# <em class="up">
# 				+24.08%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=030530" onclick="clickcr(this, 'spe.clist', '030530', '6', event);">원익홀딩스</a></th>
# <td>11,390</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,050 </td>
# <td>
# <em class="up">
# 				+21.95%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=044180" onclick="clickcr(this, 'spe.clist', '044180', '7', event);">KD</a></th>
# <td>934</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 167 </td>
# <td>
# <em class="up">
# 				+21.77%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=053260" onclick="clickcr(this, 'spe.clist', '053260', '8', event);">금강철강</a></th>
# <td>4,925</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 870 </td>
# <td>
# <em class="up">
# 				+21.45%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=120030" onclick="clickcr(this, 'spe.clist', '120030', '9', event);">조선선재</a></th>
# <td>131,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 21,900 </td>
# <td>
# <em class="up">
# 				+20.07%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=200470" onclick="clickcr(this, 'spe.clist', '200470', '10', event);">에이팩트</a></th>
# <td>3,465</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 500 </td>
# <td>
# <em class="up">
# 				+16.86%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=437730" onclick="clickcr(this, 'spe.clist', '437730', '11', event);">삼현</a></th>
# <td>17,330</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,460 </td>
# <td>
# <em class="up">
# 				+16.54%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=042520" onclick="clickcr(this, 'spe.clist', '042520', '12', event);">한스바이오메드</a></th>
# <td>9,560</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,310 </td>
# <td>
# <em class="up">
# 				+15.88%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=082270" onclick="clickcr(this, 'spe.clist', '082270', '13', event);">젬백스</a></th>
# <td>56,500</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 7,250 </td>
# <td>
# <em class="up">
# 				+14.72%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=099410" onclick="clickcr(this, 'spe.clist', '099410', '14', event);">동방선기</a></th>
# <td>5,760</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 730 </td>
# <td>
# <em class="up">
# 				+14.51%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=380550" onclick="clickcr(this, 'spe.clist', '380550', '15', event);">뉴로핏</a></th>
# <td>15,060</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,900 </td>
# <td>
# <em class="up">
# 				+14.44%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_rise.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">상승 더보기</span></em></a>
# </div>
# <div class="group_type nxt_group_type tab2" style="display:none">
# <table class="tbl_home">
# <caption>상승 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="nxt_topItems2">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=030530" onclick="clickcr(this, 'spe.clist', '030530', '1', event);">원익홀딩스</a></th>
# <td>11,400</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,060 </td>
# <td>
# <em class="up">
# 				+22.06%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=437730" onclick="clickcr(this, 'spe.clist', '437730', '2', event);">삼현</a></th>
# <td>17,320</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,450 </td>
# <td>
# <em class="up">
# 				+16.48%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=082270" onclick="clickcr(this, 'spe.clist', '082270', '3', event);">젬백스</a></th>
# <td>56,400</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 7,150 </td>
# <td>
# <em class="up">
# 				+14.52%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=067310" onclick="clickcr(this, 'spe.clist', '067310', '4', event);">하나마이크론</a></th>
# <td>15,670</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,650 </td>
# <td>
# <em class="up">
# 				+11.77%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=222800" onclick="clickcr(this, 'spe.clist', '222800', '5', event);">심텍</a></th>
# <td>27,450</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,600 </td>
# <td>
# <em class="up">
# 				+10.46%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006800" onclick="clickcr(this, 'spe.clist', '006800', '6', event);">미래에셋증권</a></th>
# <td>21,600</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,900 </td>
# <td>
# <em class="up">
# 				+9.64%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=241710" onclick="clickcr(this, 'spe.clist', '241710', '7', event);">코스메카코리아</a></th>
# <td>65,600</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 5,500 </td>
# <td>
# <em class="up">
# 				+9.15%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=007810" onclick="clickcr(this, 'spe.clist', '007810', '8', event);">코리아써키트</a></th>
# <td>14,240</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,140 </td>
# <td>
# <em class="up">
# 				+8.70%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=487570" onclick="clickcr(this, 'spe.clist', '487570', '9', event);">HS효성</a></th>
# <td>60,700</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,800 </td>
# <td>
# <em class="up">
# 				+8.59%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=253590" onclick="clickcr(this, 'spe.clist', '253590', '10', event);">네오셈</a></th>
# <td>9,120</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 700 </td>
# <td>
# <em class="up">
# 				+8.31%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=308430" onclick="clickcr(this, 'spe.clist', '308430', '11', event);">셀비온</a></th>
# <td>23,650</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,700 </td>
# <td>
# <em class="up">
# 				+7.74%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=095610" onclick="clickcr(this, 'spe.clist', '095610', '12', event);">테스</a></th>
# <td>30,900</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,200 </td>
# <td>
# <em class="up">
# 				+7.67%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=420770" onclick="clickcr(this, 'spe.clist', '420770', '13', event);">기가비스</a></th>
# <td>29,100</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,000 </td>
# <td>
# <em class="up">
# 				+7.38%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005290" onclick="clickcr(this, 'spe.clist', '005290', '14', event);">동진쎄미켐</a></th>
# <td>31,350</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,100 </td>
# <td>
# <em class="up">
# 				+7.18%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=039490" onclick="clickcr(this, 'spe.clist', '039490', '15', event);">키움증권</a></th>
# <td>227,500</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 15,000 </td>
# <td>
# <em class="up">
# 				+7.06%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/nxt_sise_rise.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">상승 더보기</span></em></a>
# </div>
# <div class="group_type krx_group_type tab3">
# <table class="tbl_home">
# <caption>하락 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems3">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=096040" onclick="clickcr(this, 'spe.blist', '096040', '1', event);">이트론</a></th>
# <td>5</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -5</td>
# <td>
# <em class="down">
# 				-50.00%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=093230" onclick="clickcr(this, 'spe.blist', '093230', '2', event);">이아이디</a></th>
# <td>83</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -19</td>
# <td>
# <em class="down">
# 				-18.63%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=342870" onclick="clickcr(this, 'spe.blist', '342870', '3', event);">오아</a></th>
# <td>15,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -3,230</td>
# <td>
# <em class="down">
# 				-17.72%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=291650" onclick="clickcr(this, 'spe.blist', '291650', '4', event);">압타머사이언스</a></th>
# <td>1,105</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -195</td>
# <td>
# <em class="down">
# 				-15.00%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=315640" onclick="clickcr(this, 'spe.blist', '315640', '5', event);">딥노이드</a></th>
# <td>4,895</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -835</td>
# <td>
# <em class="down">
# 				-14.57%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=191420" onclick="clickcr(this, 'spe.blist', '191420', '6', event);">테고사이언스</a></th>
# <td>16,900</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,850</td>
# <td>
# <em class="down">
# 				-9.87%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=108380" onclick="clickcr(this, 'spe.blist', '108380', '7', event);">대양전기공업</a></th>
# <td>29,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -3,000</td>
# <td>
# <em class="down">
# 				-9.37%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=402490" onclick="clickcr(this, 'spe.blist', '402490', '8', event);">그린리소스</a></th>
# <td>10,690</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,060</td>
# <td>
# <em class="down">
# 				-9.02%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=097230" onclick="clickcr(this, 'spe.blist', '097230', '9', event);">HJ중공업</a></th>
# <td>26,850</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,350</td>
# <td>
# <em class="down">
# 				-8.05%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=073540" onclick="clickcr(this, 'spe.blist', '073540', '10', event);">에프알텍</a></th>
# <td>2,515</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -220</td>
# <td>
# <em class="down">
# 				-8.04%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=077970" onclick="clickcr(this, 'spe.blist', '077970', '11', event);">STX엔진</a></th>
# <td>43,750</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -3,800</td>
# <td>
# <em class="down">
# 				-7.99%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=033500" onclick="clickcr(this, 'spe.blist', '033500', '12', event);">동성화인텍</a></th>
# <td>31,375</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,675</td>
# <td>
# <em class="down">
# 				-7.86%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=031860" onclick="clickcr(this, 'spe.blist', '031860', '13', event);">디에이치엑스컴퍼니</a></th>
# <td>921</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -77</td>
# <td>
# <em class="down">
# 				-7.72%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=348150" onclick="clickcr(this, 'spe.blist', '348150', '14', event);">고바이오랩</a></th>
# <td>6,180</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -470</td>
# <td>
# <em class="down">
# 				-7.07%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=071950" onclick="clickcr(this, 'spe.blist', '071950', '15', event);">코아스</a></th>
# <td>7,890</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -590</td>
# <td>
# <em class="down">
# 				-6.96%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_fall.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">하락 더보기</span></em></a>
# </div>
# <div class="group_type nxt_group_type tab3" style="display:none">
# <table class="tbl_home">
# <caption>하락 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="nxt_topItems3">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=315640" onclick="clickcr(this, 'spe.blist', '315640', '1', event);">딥노이드</a></th>
# <td>4,900</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -830</td>
# <td>
# <em class="down">
# 				-14.49%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# ...
# 							} else if (themeTopDetailItem.changeRate < 0) {
# 								sHtml += "<em class='down'>" + changeNumberFormat(themeTopDetailItem.changeRate.toFixed(2)) + "%</em>";
# 							} else {
# 								sHtml += "<em class='steady'>" + changeNumberFormat(themeTopDetailItem.changeRate.toFixed(2)) + "%</em>";
# 							}
# 							sHtml += "</p>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
#
# 					});
#
# 					// 거래상위 (KRX)
# 					jindo.$A(jindo.$$("#_topItems1 tr")).forEach(function(value, index) {
# 						var topItem = topItems[0][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.slist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeRate > 0) {
# 								sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>+" + changeRate.toFixed(2) + "%</td>";
# 							} else if (changeRate < 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 거래상위 (NXT)
# 					jindo.$A(jindo.$$("#nxt_topItems1 tr")).forEach(function(value, index) {
# 						var topItem = nxtTopItems[0][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.slist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeRate > 0) {
# 								sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>+" + changeRate.toFixed(2) + "%</td>";
# 							} else if (changeRate < 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 상승 (KRX)
# 					jindo.$A(jindo.$$("#_topItems2 tr")).forEach(function(value, index) {
# 						var topItem = topItems[1][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var risefall = topItem.risefall;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
#
# 							if (changeVal != 0) {
# 								if (risefall == '1') {
# 									sHtml += "<td><em class='bu_p bu_pup2'><span class='blind'>상한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								} else {
# 									sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								}
# 								sHtml += "<td>+" + changeRate.toFixed(2)+ "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 상승 (NXT)
# 					jindo.$A(jindo.$$("#nxt_topItems2 tr")).forEach(function(value, index) {
# 						var topItem = nxtTopItems[1][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var risefall = topItem.risefall;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
#
# 							if (changeVal != 0) {
# 								if (risefall == '1') {
# 									sHtml += "<td><em class='bu_p bu_pup2'><span class='blind'>상한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								} else {
# 									sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								}
# 								sHtml += "<td>+" + changeRate.toFixed(2)+ "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 하락 (KRX)
# 					jindo.$A(jindo.$$("#_topItems3 tr")).forEach(function(value, index) {
# 						var topItem = topItems[2][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var risefall = topItem.risefall;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.blist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeVal != 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								if (risefall == '4') {
# 									sHtml += "<td><em class='bu_p bu_pdn2'><span class='blind'>하한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								} else {
# 									sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								}
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 하락 (NXT)
# 					jindo.$A(jindo.$$("#nxt_topItems3 tr")).forEach(function(value, index) {
# 						var topItem = nxtTopItems[2][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var risefall = topItem.risefall;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.blist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeVal != 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								if (risefall == '4') {
# 									sHtml += "<td><em class='bu_p bu_pdn2'><span class='blind'>하한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								} else {
# 									sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								}
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
#
# 					// 시가총액 상위 (KRX)
# 					jindo.$A(jindo.$$("#_topItems4 tr")).forEach(function(value, index) {
# 						var topItem = topItems[3][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeRate > 0) {
# 								sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>+" + changeRate.toFixed(2) + "%</td>";
# 							} else if (changeRate < 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 시가총액 상위 (NXT)
# 					jindo.$A(jindo.$$("#nxt_topItems4 tr")).forEach(function(value, index) {
# 						var topItem = nxtTopItems[3][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeRate > 0) {
# 								sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>+" + changeRate.toFixed(2) + "%</td>";
# 							} else if (changeRate < 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 인기 검색 종목
# 					jindo.$A(jindo.$$(".aside_popular tbody tr")).forEach(function(value, index) {
# 						var popularItem = searchList[index];
# 						var uiCount = index + 1;
# 						var changeVal = popularItem.change_val;
# 						var nowVal = popularItem.now_val;
# 						var itemcode = popularItem.itemcode;
#
# 						setUpDownClass(changeVal, value);
#
# 						var sHtml = "";
# 						sHtml += "<th scope=\'row\'><em>" + uiCount + ".</em><a href=\'/item/main.naver?code=" + itemcode + "\' onClick='clickcr(this, \"boa.list\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 						sHtml += cutStringByByte(popularItem.itemname, 12, "..") + "</a></th>";
# 						sHtml += "<td>" + changeNumberFormat(nowVal) + "</td>";
#
# 						if (popularItem.risefall == 1) {
# 							sHtml += "<td><em class=\'bu_p bu_pup2\'><span class=\'blind\'>상한가</span></em><span class=\'tah p11 red02\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else if (popularItem.risefall == 2) {
# 							sHtml += "<td><em class=\'bu_p bu_pup'><span class=\'blind\'>상승</span></em><span class=\'tah p11 red02\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else if (popularItem.risefall == 3) {
# 							sHtml += "<td><span class=\'tah p11\'> 0 </span></td>";
# 						} else if (popularItem.risefall == 4) {
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class=\'bu_p bu_pdn2\'><span class=\'blind\'>하한가</span></em><span class=\'tah p11 nv01\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else{
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class=\'bu_p bu_pdn'\><span class=\'blind\'>하락</span></em><span class=\'tah p11 nv01\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
#
# 					});
#
# 					startInformationTimer();
# 				}
# 			}
# 		},
# 		timeout : 2,
# 		ontimeout : function() {
# 			startInformationTimer();
# 		},
# 		async : true
# 	});
# 	oUpdateAjax.request();
# }
#
# function getIndexItemLinkTemplateValues(todayIndexDealTrendLink, index) {
# 	values = {
# 			_todayIndexDealTrendLink : todayIndexDealTrendLink[index],
# 			_todayIndexItemUpperLink : "/sise/sise_upper.naver?sosok=" + index,
# 			_todayIndexItemRiseLink : "/sise/sise_rise.naver?sosok=" + index,
# 			_todayIndexItemSteadyLink : "/sise/sise_steady.naver?sosok=" + index,
# 			_todayIndexItemFallLink : "/sise/sise_fall.naver?sosok=" + index,
# 			_todayIndexItemLowerLink : "/sise/sise_lower.naver?sosok=" + index
# 	};
#
# 	return values;
# }
#
# // up, down, same 클래스 생성 기능
# function setUpDownClass(sChangeVal, eValue) {
# 	if (sChangeVal > 0) {
# 		jindo.$Element(eValue).className("up");
# 	} else if (sChangeVal < 0) {
# 		jindo.$Element(eValue).className("down");
# 	} else {
# 		jindo.$Element(eValue).className("same");
# 	}
# }
#
# function setUpDnClass(value){
# 	var className = "";
# 	if (value > 0){
# 		className = "up";
# 	} else if(value < 0){
# 		className = "dn";
# 	}
#
# 	return className;
# }
#
# function mainPageDomReadyFn() {
# 	startInformationTimer();
# 	Polling.init();
# }
#
# function togglePannel(layerId) {
#     var elTargetLayer = jindo.$Element(jindo.$$.getSingle("#" + layerId));
#
#     if (elTargetLayer != null) {
#         if (elTargetLayer.visible()) {
#             hidePannel(layerId);
#         } else {
#             showPannel(layerId);
#         }
#     }
# }
#
# function showPannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='block';
# }
#
# function hidePannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='none';
# }
# function getOverMarketPriceFormat(tradingSessionType, overMarketPrice) {
# 	if (tradingSessionType == 'PRE_MARKET') {
# 		return "<span class='pre_after_badge'>Pre</span>" + changeNumberFormat(overMarketPrice);
# 	} else if (tradingSessionType == 'AFTER_MARKET') {
# 		return "<span class='pre_after_badge'>After</span>" + changeNumberFormat(overMarketPrice);
# 	} else {
# 		return changeNumberFormat(overMarketPrice);
# 	}
# }
# function removeText(text){
# 	if (text != null) {
# 		return text.toString().replace(/[^0-9|.]/g, '')
# 	}
# 	return text;
# }
# function changeNumberFormat(vNumber){
# 	var sUnderNumber = "";
# 	var sNumberString = vNumber || 0;
# 	sNumberString = (typeof sNumberString != "String") ? String(sNumberString) : sNumberString;
#
# 	if(sNumberString.indexOf(".") > -1){
# 		var aNumber = sNumberString.split(".");
# 		sNumberString = aNumber[0];
# 		sUnderNumber = "." + aNumber[1];
# 	}
#
# 	return sNumberString.replace(/(\d)(?=(\d{3})+$)/igm, "$1,") + sUnderNumber;
# }
#
# // 1분 리플레시, 실시간 시세 폴링, 이미지 리플레시
# jindo.$Fn(mainPageDomReadyFn).attach(document, "domready");
#
# </script>
# </body>
# </html>

# %%
type(soup.find('a'))
soup.find('a')
# Out:
# <a href="#menu" tabindex="1"><span>메인 메뉴로 바로가기</span></a>

# %%
type(soup.find_all('a'))
# find_all은 tag로 변경해서 사용해야한다. resultset으로 주기 때문
# Out:
# bs4.element.ResultSet

# %%
# html 문서 안에 존재하는 모든 a택의 정보를 확인
soup.find_all('a')
# Out:
# [<a href="#topAsideButton"><span>상단영역 바로가기</span></a>,
#  <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a>,
#  <a href="#newsstand"><span>새소식 블록 바로가기</span></a>,
#  <a href="#shopping"><span>쇼핑 블록 바로가기</span></a>,
#  <a href="#feed"><span>관심사 블록 바로가기</span></a>,
#  <a href="#account"><span>MY 영역 바로가기</span></a>,
#  <a href="#widgetboard"><span>위젯 보드 바로가기</span></a>,
#  <a href="#viewSetting"><span>보기 설정 바로가기</span></a>]

# %%
# naver 메인페이지는 비동기 방식 페이지이므로 전체의 html을 request만 가지고 로드가 불가능
# 'https://finance.naver.com/' 이 주소의 html을 불러와서 실습

res = requests.get('http://finance.naver.com/')
#문자열로 저장
html_data = res.text
#beautifulSoup을 이용하여 데이터 파싱
soup = bs(html_data, 'html.parser')

# %%
# soup 에서
len(
    soup.find_all(
        'div',
        attrs = {
            'class' : 'section_sise_top'
        } 
    )
)
# Out:
# 1

# %%
div_data = soup.find(
    'div',
    attrs = {
        'class' : 'section_sise_top'
    }
)

# %%
# div_data_table 태그의 개수를 확인
len(
    div_data.find_all(
        'table',
        attrs = {
            'class' : 'tbl_home'
        }
    )
)
# div_data 에는 테이블이 8개 존재 -> KRX 4, NXT 4
# Out:
# 8

# %%
table_list = div_data.find_all(
    'table'
)

# %%
table_data = table_list[0]

# %%
# table_data에서 thead를 찾는다
thead_data = table_data.find('thead')

# %%
# 데이터들은 열을 나타내는 태그에 존재
# th 태그들에 데이터가 존재
# th 태그를 모두 찾는다.
th_list = thead_data.find_all('th')

# %%
# th 데이터에서 문자만 추출
# map( 함수->lambda, 1차원 데이터)
cols = list(
    map(
        lambda x : x.string,
        th_list
    )
)

# %%
# able_data에서 tbody 데이터를 찾는다
tbody_data = table_data.find('tbody')

# %%
# tbody 데이터에서 모든 tr 태그를 찾는다
# (tr 안에 th, td 데이터를 이용하여 1차원 데이터 구성)
tr_list = tbody_data.find_all('tr')

# %%
tr_list[0]
# Out:
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>1,248</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 31</td>
# <td>
# <em class="down">
# 				-2.42%
# 				</em>
# </td>
# </tr>

# %%
tr_list[0].find_all(['th', 'td'])
# Out:
# [<th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>,
#  <td>1,248</td>,
#  <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 31</td>,
#  <td>
#  <em class="down">
#  				-2.42%
#  				</em>
#  </td>]

# %%
# tr_list에서 첫 번째 데이터를 이용하여 th, td 데이터를 찾는다.
list(
    map(
        lambda x: x.get_text().strip(),
        tr_list[0].find_all(['th','td'])
    )
)
# Out:
# ['KODEX 200선물인버스2X', '1,248', '하락 31', '-2.42%']

# %%
# 비어있는 리스트 생성
values = []
# tr_list를 이용하여 반복문을 실행

for td_data in tr_list:
    # td_data에는 반복 실행할 때마다 tr_list 의 첫번째, 두번째 ,, 대입
    value = list(
        map(
            lambda x: x.get_text().strip(),
            td_data.find_all(['th','td'])
        )   
    )  
    values.append(value)     
values
# Out:
# [['KODEX 200선물인버스2X', '1,248', '하락 31', '-2.42%'],
#  ['이트론', '5', '하락 5', '-50.00%'],
#  ['엔케이', '1,393', '상승 3', '+0.22%'],
#  ['씨피시스템', '2,540', '상승 130', '+5.39%'],
#  ['KD', '934', '상승 167', '+21.77%'],
#  ['보성파워텍', '4,310', '상승 355', '+8.98%'],
#  ['이아이디', '83', '하락 19', '-18.63%'],
#  ['KODEX 인버스', '3,412', '하락 48', '-1.39%'],
#  ['한국선재', '4,280', '상승 360', '+9.18%'],
#  ['일승', '8,140', '상승 1,610', '+24.66%'],
#  ['KODEX 2차전지산업레버리지', '1,021', '상승 21', '+2.10%'],
#  ['대창솔루션', '511', '상승 20', '+4.07%'],
#  ['이화전기', '319', '상승 24', '+8.14%'],
#  ['미투온', '6,400', '상승 600', '+10.34%'],
#  ['상상인증권', '845', '상승 164', '+24.08%']]

# %%
import pandas as pd

# %%
df = pd.DataFrame(values, columns = cols)
df
# Out:
#                  종목명    현재가      전일대비      등락률
# 0   KODEX 200선물인버스2X  1,248     하락 31   -2.42%
# 1                이트론      5      하락 5  -50.00%
# 2                엔케이  1,393      상승 3   +0.22%
# 3              씨피시스템  2,540    상승 130   +5.39%
# 4                 KD    934    상승 167  +21.77%
# 5              보성파워텍  4,310    상승 355   +8.98%
# 6               이아이디     83     하락 19  -18.63%
# 7          KODEX 인버스  3,412     하락 48   -1.39%
# 8               한국선재  4,280    상승 360   +9.18%
# 9                 일승  8,140  상승 1,610  +24.66%
# 10  KODEX 2차전지산업레버리지  1,021     상승 21   +2.10%
# 11             대창솔루션    511     상승 20   +4.07%
# 12              이화전기    319     상승 24   +8.14%
# 13               미투온  6,400    상승 600  +10.34%
# 14             상상인증권    845    상승 164  +24.08%

# %%
# section_sise_top class 이름을 가진 div 태그의 모든 table을 데이터프레임으로 생성

file_num = 1
for table_data in table_list:
    thead_data = table_data.find('thead')
    th_list = thead_data.find_all('th')
    cols = list(
        map(
            lambda x : x.string,
            th_list
        )
    )
    tbody_data = table_data.find('tbody')
    tr_list = tbody_data.find_all('tr')
    values = []
    # tr_list를 이용하여 반복문을 실행

    for td_data in tr_list:
        # td_data에는 반복 실행할 때마다 tr_list 의 첫번째, 두번째 ,, 대입
        value = list(
            map(
                lambda x: x.get_text().strip(),
                td_data.find_all(['th','td'])
            )   
        )  
        values.append(value) 

    globals()[f'df{file_num}'] = pd.DataFrame(values, columns = cols)
    # 각각의 파일로 저장
    globals()[f'df{file_num}'].to_csv(f'df{file_num}.csv')
    file_num += 1

# %%
df8
# Out:
#           종목명        현재가       전일대비     등락률
# 0        삼성전자     71,100   상승 1,000  +1.43%
# 1      SK하이닉스    287,500  상승 10,500  +3.79%
# 2    LG에너지솔루션    347,000   상승 3,500  +1.02%
# 3    삼성바이오로직스  1,035,000   상승 4,000  +0.39%
# 4   한화에어로스페이스    947,000   하락 4,000  -0.42%
# 5         현대차    220,000   상승 1,500  +0.69%
# 6     HD현대중공업    502,000   하락 9,000  -1.76%
# 7        KB금융    109,300   상승 2,600  +2.44%
# 8          기아    105,700     상승 800  +0.76%
# 9     두산에너빌리티     62,000   상승 1,100  +1.81%
# 10       셀트리온    169,700     하락 300  -0.18%
# 11      NAVER    232,000   상승 4,000  +1.75%
# 12       한화오션    110,000     하락 900  -0.81%
# 13       신한지주     65,400   상승 1,000  +1.55%
# 14       삼성생명    158,200   상승 7,800  +5.19%

# %%
type(div_data)
# Out:
# bs4.element.Tag

# %%
str(div_data)

# %%
# html 문서(url, file, html로 이루어진 문자)를 read_html() 함수에 입력하면 -> 
# html 안에 있는 table 태그를 찾아서 데이터프레임으로 생성
pd.read_html(str(div_data))
# 테이블만 가능
# Out:
# /var/folders/v0/r6b3g15j6gd1x8947g8ly2qr0000gn/T/ipykernel_74575/230583022.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(str(div_data))
# [                 종목명   현재가      전일대비      등락률
#  0   KODEX 200선물인버스2X  1248     하락 31   -2.42%
#  1                이트론     5      하락 5  -50.00%
#  2                엔케이  1393      상승 3   +0.22%
#  3              씨피시스템  2540    상승 130   +5.39%
#  4                 KD   934    상승 167  +21.77%
#  5              보성파워텍  4310    상승 355   +8.98%
#  6               이아이디    83     하락 19  -18.63%
#  7          KODEX 인버스  3412     하락 48   -1.39%
#  8               한국선재  4280    상승 360   +9.18%
#  9                 일승  8140  상승 1,610  +24.66%
#  10  KODEX 2차전지산업레버리지  1021     상승 21   +2.10%
#  11             대창솔루션   511     상승 20   +4.07%
#  12              이화전기   319     상승 24   +8.14%
#  13               미투온  6400    상승 600  +10.34%
#  14             상상인증권   845    상승 164  +24.08%,
#          종목명    현재가      전일대비      등락률
#  0    오리엔탈정공  11320    상승 420   +3.85%
#  1     원익홀딩스  11400  상승 2,060  +22.06%
#  2        삼현  17320  상승 2,450  +16.48%
#  3     세진중공업  22050  하락 1,450   -6.17%
#  4       네오셈   9120    상승 700   +8.31%
#  5    하나마이크론  15670  상승 1,650  +11.77%
#  6    미래에셋증권  21600  상승 1,900   +9.64%
#  7   두산에너빌리티  62000  상승 1,100   +1.81%
#  8   한선엔지니어링   8630    상승 460   +5.63%
#  9      삼성전자  71100  상승 1,000   +1.43%
#  10    삼성중공업  20950    하락 300   -1.41%
#  11  메타바이오메드   6340     하락 60   -0.94%
#  12   엘앤씨바이오  50700  상승 1,750   +3.58%
#  13    제주반도체  18060    상승 350   +1.98%
#  14    에스엔시스  48700  하락 2,500   -4.88%,
#          종목명     현재가       전일대비      등락률
#  0    동일스틸럭스    3640    상한가 840  +30.00%
#  1      셀루메드     802    상한가 185  +29.98%
#  2      디에이피    2510    상한가 578  +29.92%
#  3        일승    8140   상승 1,610  +24.66%
#  4     상상인증권     845     상승 164  +24.08%
#  5     원익홀딩스   11390   상승 2,050  +21.95%
#  6        KD     934     상승 167  +21.77%
#  7      금강철강    4925     상승 870  +21.45%
#  8      조선선재  131000  상승 21,900  +20.07%
#  9      에이팩트    3465     상승 500  +16.86%
#  10       삼현   17330   상승 2,460  +16.54%
#  11  한스바이오메드    9560   상승 1,310  +15.88%
#  12      젬백스   56500   상승 7,250  +14.72%
#  13     동방선기    5760     상승 730  +14.51%
#  14      뉴로핏   15060   상승 1,900  +14.44%,
#          종목명     현재가       전일대비      등락률
#  0     원익홀딩스   11400   상승 2,060  +22.06%
#  1        삼현   17320   상승 2,450  +16.48%
#  2       젬백스   56400   상승 7,150  +14.52%
#  3    하나마이크론   15670   상승 1,650  +11.77%
#  4        심텍   27450   상승 2,600  +10.46%
#  5    미래에셋증권   21600   상승 1,900   +9.64%
#  6   코스메카코리아   65600   상승 5,500   +9.15%
#  7    코리아써키트   14240   상승 1,140   +8.70%
#  8      HS효성   60700   상승 4,800   +8.59%
#  9       네오셈    9120     상승 700   +8.31%
#  10      셀비온   23650   상승 1,700   +7.74%
#  11       테스   30900   상승 2,200   +7.67%
#  12     기가비스   29100   상승 2,000   +7.38%
#  13    동진쎄미켐   31350   상승 2,100   +7.18%
#  14     키움증권  227500  상승 15,000   +7.06%,
#            종목명    현재가       전일대비      등락률
#  0         이트론      5      하락 -5  -50.00%
#  1        이아이디     83     하락 -19  -18.63%
#  2          오아  15000  하락 -3,230  -17.72%
#  3     압타머사이언스   1105    하락 -195  -15.00%
#  4        딥노이드   4895    하락 -835  -14.57%
#  5      테고사이언스  16900  하락 -1,850   -9.87%
#  6      대양전기공업  29000  하락 -3,000   -9.37%
#  7       그린리소스  10690  하락 -1,060   -9.02%
#  8       HJ중공업  26850  하락 -2,350   -8.05%
#  9        에프알텍   2515    하락 -220   -8.04%
#  10      STX엔진  43750  하락 -3,800   -7.99%
#  11      동성화인텍  31375  하락 -2,675   -7.86%
#  12  디에이치엑스컴퍼니    921     하락 -77   -7.72%
#  13      고바이오랩   6180    하락 -470   -7.07%
#  14        코아스   7890    하락 -590   -6.96%,
#           종목명     현재가        전일대비      등락률
#  0       딥노이드    4900     하락 -830  -14.49%
#  1      그린리소스   10720   하락 -1,030   -8.77%
#  2      동성화인텍   31350   하락 -2,700   -7.93%
#  3      STX엔진   43800   하락 -3,750   -7.89%
#  4      세진중공업   22050   하락 -1,450   -6.17%
#  5       한국카본   33450   하락 -2,100   -5.91%
#  6        솔루엠   18240   하락 -1,110   -5.74%
#  7     우리기술투자   10380     하락 -580   -5.29%
#  8       한미약품  290500  하락 -15,500   -5.07%
#  9      더존비즈온   80800   하락 -4,300   -5.05%
#  10      에스티팜   93400   하락 -4,900   -4.98%
#  11     에스엔시스   48700   하락 -2,500   -4.88%
#  12        태광   26150   하락 -1,200   -4.39%
#  13  HD현대마린엔진   87000   하락 -3,900   -4.29%
#  14       메지온   53500   하락 -2,300   -4.12%,
#            종목명      현재가       전일대비     등락률
#  0        삼성전자    71100   상승 1,000  +1.43%
#  1      SK하이닉스   287250  상승 10,250  +3.70%
#  2    LG에너지솔루션   347250   상승 3,750  +1.09%
#  3    삼성바이오로직스  1035000   상승 4,000  +0.39%
#  4   한화에어로스페이스   946000   하락 5,000  -0.53%
#  5       삼성전자우    58100     상승 600  +1.04%
#  6         현대차   220500   상승 2,000  +0.92%
#  7     HD현대중공업   502000   하락 9,000  -1.76%
#  8        KB금융   109400   상승 2,700  +2.53%
#  9          기아   105800     상승 900  +0.86%
#  10    두산에너빌리티    62100   상승 1,200  +1.97%
#  11       셀트리온   169800     하락 200  -0.12%
#  12      NAVER   232250   상승 4,250  +1.86%
#  13       한화오션   109900   하락 1,000  -0.90%
#  14       신한지주    65400   상승 1,000  +1.55%,
#            종목명      현재가       전일대비     등락률
#  0        삼성전자    71100   상승 1,000  +1.43%
#  1      SK하이닉스   287500  상승 10,500  +3.79%
#  2    LG에너지솔루션   347000   상승 3,500  +1.02%
#  3    삼성바이오로직스  1035000   상승 4,000  +0.39%
#  4   한화에어로스페이스   947000   하락 4,000  -0.42%
#  5         현대차   220000   상승 1,500  +0.69%
#  6     HD현대중공업   502000   하락 9,000  -1.76%
#  7        KB금융   109300   상승 2,600  +2.44%
#  8          기아   105700     상승 800  +0.76%
#  9     두산에너빌리티    62000   상승 1,100  +1.81%
#  10       셀트리온   169700     하락 300  -0.18%
#  11      NAVER   232000   상승 4,000  +1.75%
#  12       한화오션   110000     하락 900  -0.81%
#  13       신한지주    65400   상승 1,000  +1.55%
#  14       삼성생명   158200   상승 7,800  +5.19%]

# %%
# 데이터프레임을 sqlserver에 insert
# !pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.43-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/eunseo/Documents/data_boot/venv/lib/python3.13/site-packages (from sqlalchemy) (4.15.0)
# Downloading sqlalchemy-2.0.43-cp313-cp313-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 32.3 MB/s  0:00:00
# Installing collected packages: sqlalchemy
# Successfully installed sqlalchemy-2.0.43

# %%
from sqlalchemy import create_engine

# %%
# DB server의 정보를 입력
engine = create_engine(
    "mysql+pymysql://root@localhost:3306/multicam"
)

# %%
# to_sql() 매개변수
# name : 테이블의 이름
# con : 데이터베이스의 주소
# index : index 데이터를 포함할 것인가(기본값 : True)
# if_exists : replace(교체), fail(실패, 기본값), append(데이터를 추가)
df1.to_sql(
    name = 'test1234',
    con = engine
)

# %%
# pymysql을 이용하여 데이터프레임의 정보를 DB에 insert
from database import MyDB

# %%
db1 = MyDB()

# %%
table_query = """
    create table
    if not exists
    `krx_top`(
    `No` int primary key auto_increment,
    `종목명` varchar(50) not null,
    `현재가` int not null,
    `전일대비` varchar(20) not null,
    `등락률` varchar(20)
    )
"""

db1.sql_query(table_query)
# Out:
# 'Query OK'

# %%
df1.loc[0,].to_list()
# Out:
# ['KODEX 200선물인버스2X', '1,248', '하락 31', '-2.42%']

# %%
insert_query = """
    insert into
    `krx_top`(
    `종목명`, `현재가`, `전일대비`, `등락률`
    )
    values
    (%s, %s, %s, %s)
"""

# %%
df1['현재가'] = df1['현재가'].str.replace(',', '')
# .str은 잠깐 문자열함수를 사용할 수 있는 형태로 바꿔줌

# %%
db1.sql_query(insert_query, *df1.loc[0,].to_list())
# 현재가 컬럼의 데이터가 숫자형으로 변환 불가능 -> ',' 제거
# Out:
# 'Query OK'

# %%
# Cursor에 데이터를 대입
for i in range (0, len(df1)):
    db1.sql_query(insert_query, *df1.loc[i,].to_list())

# %%
# DB server와 cursor의 동기화
db1.commit_db()
# Out:
# Commit 완료
# 서버와의 연결 종료
